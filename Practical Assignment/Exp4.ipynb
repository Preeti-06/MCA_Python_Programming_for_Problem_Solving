# %%
lst = [12, 45, 33, 21, 88]
item = int(input("Enter item: "))

if item in lst:
    print("Item found at position", lst.index(item)+1)
else:
    print("Item not found.")
# Out:
# Enter item: 12
# Item found at position 1
