# %%
def dice_probability():
    return 1/6

def coin_probability():
    return 1/2

print("Dice probability:", dice_probability())
print("Coin probability:", coin_probability())
# Out:
# Dice probability: 0.16666666666666666
# Coin probability: 0.5
