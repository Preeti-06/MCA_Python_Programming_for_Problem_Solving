# %%
files = ['report.pdf', 'data.csv', 'photo.jpg', 'summary.pdf', 'script.py']

result = {}

for f in files:
    ext = f.split(".")[-1]
    result.setdefault(ext, []).append(f)

print(result)
# Out:
# {'pdf': ['report.pdf', 'summary.pdf'], 'csv': ['data.csv'], 'jpg': ['photo.jpg'], 'py': ['script.py']}
