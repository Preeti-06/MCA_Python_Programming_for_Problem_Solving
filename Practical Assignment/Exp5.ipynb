# %%
employees = [
    {"name": "John", "salary": 45000},
    {"name": "Mary", "salary": 52000},
    {"name": "Alex", "salary": 48000}
]

sorted_list = sorted(employees, key=lambda x: x["salary"])
print(sorted_list)
# Out:
# [{'name': 'John', 'salary': 45000}, {'name': 'Alex', 'salary': 48000}, {'name': 'Mary', 'salary': 52000}]
