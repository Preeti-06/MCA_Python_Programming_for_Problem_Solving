# %%
import statistics as st

nums = list(map(int, input("Enter numbers: ").split()))

print("Mean =", st.mean(nums))
print("Median =", st.median(nums))
print("Mode =", st.mode(nums))
# Out:
# Enter numbers: 2 4 6 6 8
# Mean = 5.2
# Median = 6
# Mode = 6
