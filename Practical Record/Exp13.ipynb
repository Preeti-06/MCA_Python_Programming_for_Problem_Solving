# %%
import random
import string

uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase
digits = string.digits
symbols = "!@#$*"

first_char = random.choice(uppercase + digits)
remaining = uppercase + lowercase + digits + symbols

password = first_char + ''.join(random.choice(remaining) for _ in range(11))
print("Password:", password)
# Out:
# Password: VXCx*4L1o1xI
