# %%
n = int(input("Enter number: "))

print("Binary:", bin(n)[2:])
print("Octal:", oct(n)[2:])
print("Hexadecimal:", hex(n)[2:])
# Out:
# Enter number: 35
# Binary: 100011
# Octal: 43
# Hexadecimal: 23
