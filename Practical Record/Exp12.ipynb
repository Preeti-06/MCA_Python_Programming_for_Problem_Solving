# %%
import random

students = ["Aman", "Preeti", "Rahul", "Neha", "Rohit"]

cr = random.choice(students)
print("CR:", cr)

random.shuffle(students)
print("Shuffled List:", students)
# Out:
# CR: Preeti
# Shuffled List: ['Neha', 'Rahul', 'Preeti', 'Aman', 'Rohit']
